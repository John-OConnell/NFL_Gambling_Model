# %%
from matplotlib import pyplot as plt
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
# Out:
# /Users/johnoconnell/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
stats_2010 = pd.read_csv('stats_2010.csv')
stats_2011 = pd.read_csv('stats_2011.csv')
stats_2012 = pd.read_csv('stats_2012.csv')
stats_2013 = pd.read_csv('stats_2013.csv')
stats_2014 = pd.read_csv('stats_2014.csv')
stats_2015 = pd.read_csv('stats_2015.csv')
stats_2016 = pd.read_csv('stats_2016.csv')
stats_2017 = pd.read_csv('stats_2017.csv')
stats_2018 = pd.read_csv('stats_2018.csv')
stats_2019 = pd.read_csv('stats_2019.csv')
stats_2020 = pd.read_csv('stats_2020.csv')
stats_2021 = pd.read_csv('stats_2021.csv')
stats_2022 = pd.read_csv('stats_2022.csv')

# %%
combined = stats_2010.append(stats_2011)
# Out:
# /var/folders/jw/95zp9jr92y72x0m_9wppzqmw0000gn/T/ipykernel_21238/1344768360.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined = stats_2010.append(stats_2011)

# %%
combined = combined.append(stats_2012)
combined = combined.append(stats_2013)
combined = combined.append(stats_2014)
combined = combined.append(stats_2015)
combined = combined.append(stats_2016)
combined = combined.append(stats_2017)
combined = combined.append(stats_2018)
combined = combined.append(stats_2019)
combined = combined.append(stats_2020)
combined = combined.append(stats_2021)
combined = combined.append(stats_2022)
# Out:
# /var/folders/jw/95zp9jr92y72x0m_9wppzqmw0000gn/T/ipykernel_21238/3421938700.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined = combined.append(stats_2012)
# /var/folders/jw/95zp9jr92y72x0m_9wppzqmw0000gn/T/ipykernel_21238/3421938700.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined = combined.append(stats_2013)
# /var/folders/jw/95zp9jr92y72x0m_9wppzqmw0000gn/T/ipykernel_21238/3421938700.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined = combined.append(stats_2014)
# /var/folders/jw/95zp9jr92y72x0m_9wppzqmw0000gn/T/ipykernel_21238/3421938700.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined = combined.append(stats_2015)
# /var/folders/jw/95zp9jr92y72x0m_9wppzqmw0000gn/T/ipykernel_21238/3421938700.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined = combined.append(stats_2016)
# /var/folders/jw/95zp9jr92y72x0m_9wppzqmw0000gn/T/ipykernel_21238/3421938700.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined = combined.append(stats_2017)
# /var/folders/jw/95zp9jr92y72x0m_9wppzqmw0000gn/T/ipykernel_21238/3421938700.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined = combined.append(stats_2018)
# /var/folders/jw/95zp9jr92y72x0m_9wppzqmw0000gn/T/ipykernel_21238/3421938700.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined = combined.append(stats_2019)
# /var/folders/jw/95zp9jr92y72x0m_9wppzqmw0000gn/T/ipykernel_21238/3421938700.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined = combined.append(stats_2020)
# /var/folders/jw/95zp9jr92y72x0m_9wppzqmw0000gn/T/ipykernel_21238/3421938700.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined = combined.append(stats_2021)
# /var/folders/jw/95zp9jr92y72x0m_9wppzqmw0000gn/T/ipykernel_21238/3421938700.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined = combined.append(stats_2022)

# %%
print(combined)
# Out:
#     Unnamed: 0 team_abbr  points_for   yards   plays  yards_per_plbay  \
# 0            0       crd       289.0  4309.0   931.0              4.6
# 1            1       atl       414.0  5458.0  1097.0              5.0
# 2            2       rav       357.0  5166.0  1018.0              5.1
# 3            3       buf       283.0  4878.0   954.0              5.1
# 4            4       car       196.0  4135.0   962.0              4.3
# ..         ...       ...         ...     ...     ...              ...
# 27          27       sfo       450.0  6216.0  1047.0              5.9
# 28          28       sea       407.0  5976.0  1044.0              5.7
# 29          29       tam       313.0  5894.0  1159.0              5.1
# 30          30       oti       298.0  5045.0   992.0              5.1
# 31          31       was       321.0  5615.0  1140.0              4.9
#
#     turnovers  fumbles_lost  first_downs  completions  ...  \
# 0        35.0          16.0        241.0        285.0  ...
# 1        17.0           8.0        353.0        361.0  ...
# 2        20.0          10.0        303.0        308.0  ...
# 3        39.0          18.0        263.0        296.0  ...
# 4        37.0          16.0        225.0        256.0  ...
# ..        ...           ...          ...          ...  ...
# 27       17.0           8.0        347.0        338.0  ...
# 28       23.0          11.0        346.0        399.0  ...
# 29       22.0          12.0        346.0        499.0  ...
# 30       23.0          12.0        277.0        285.0  ...
# 31       23.0           7.0        339.0        344.0  ...
#
#     red_zone_td_percentage  o_3D_attempts  o_3D_conversions  \
# 0                     43.2          233.0              87.0
# 1                     60.3          201.0              79.0
# 2                     49.0          229.0              87.0
# 3                     51.4          227.0              98.0
# 4                     30.3          213.0              81.0
# ..                     ...            ...               ...
# 27                    54.0          218.0              85.0
# 28                    47.3          227.0              96.0
# 29                    52.0          236.0              87.0
# 30                    64.3          225.0              77.0
# 31                    51.1          210.0              67.0
#
#     o_3D_conversion_percentage  o_4D_attempts  o_4D_conversions  \
# 0                         37.3           17.0               9.0
# 1                         39.3           17.0               9.0
# 2                         38.0           12.0               6.0
# 3                         43.2           10.0               7.0
# 4                         38.0            9.0               4.0
# ..                         ...            ...               ...
# 27                        39.0           25.0              10.0
# 28                        42.3           28.0              11.0
# 29                        36.9           24.0              14.0
# 30                        34.2           26.0              19.0
# 31                        31.9           25.0              12.0
#
#     o_4D_conversion_percentage  o_red_zone_attempts  o_red_zone_tds  \
# 0                         52.9                 69.0            27.0
# 1                         52.9                 42.0            23.0
# 2                         50.0                 40.0            17.0
# 3                         70.0                 54.0            33.0
# 4                         44.4                 66.0            32.0
# ..                         ...                  ...             ...
# 27                        40.0                 37.0            21.0
# 28                        39.3                 52.0            31.0
# 29                        58.3                 48.0            30.0
# 30                        73.1                 49.0            27.0
# 31                        48.0                 52.0            27.0
#
#     o_red_zone_td_percentage
# 0                       39.1
# 1                       54.8
# 2                       42.5
# 3                       61.1
# 4                       48.5
# ..                       ...
# 27                      56.8
# 28                      59.6
# 29                      62.5
# 30                      55.1
# 31                      51.9
#
# [416 rows x 70 columns]

# %%
combined.describe()
# Out:
#        Unnamed: 0  points_for        yards        plays  yards_per_plbay  \
# count   416.00000  416.000000   416.000000   416.000000       416.000000
# mean     15.50000  367.757212  5597.490385  1029.485577         5.432452
# std       9.24421   70.557103   588.317958    51.229084         0.475957
# min       0.00000  193.000000  3865.000000   878.000000         4.100000
# 25%       7.75000  318.750000  5183.750000   997.750000         5.100000
# 50%      15.50000  365.500000  5581.500000  1022.500000         5.400000
# 75%      23.25000  414.000000  6004.750000  1060.000000         5.800000
# max      31.00000  606.000000  7474.000000  1191.000000         6.800000
#
#         turnovers  fumbles_lost  first_downs  completions  pass_attempts  ...  \
# count  416.000000    416.000000   416.000000   416.000000     416.000000  ...
# mean    23.266827      9.324519   323.180288   351.620192     559.822115  ...
# std      6.187703      3.169581    36.895994    48.459746      61.126234  ...
# min      8.000000      2.000000   225.000000   217.000000     377.000000  ...
# 25%     19.000000      7.000000   297.750000   315.000000     516.750000  ...
# 50%     23.000000      9.000000   323.000000   354.000000     562.500000  ...
# 75%     27.000000     11.000000   349.000000   380.250000     603.250000  ...
# max     44.000000     22.000000   444.000000   499.000000     751.000000  ...
#
#        red_zone_td_percentage  o_3D_attempts  o_3D_conversions  \
# count              416.000000     416.000000        416.000000
# mean                55.227885     211.733173         82.884615
# std                  8.276399      12.796590          9.893951
# min                 27.000000     176.000000         47.000000
# 25%                 50.000000     203.000000         76.000000
# 50%                 54.600000     211.000000         82.000000
# 75%                 60.450000     221.000000         89.000000
# max                 80.000000     245.000000        111.000000
#
#        o_3D_conversion_percentage  o_4D_attempts  o_4D_conversions  \
# count                  416.000000     416.000000        416.000000
# mean                    39.153125      16.944712          8.471154
# std                      4.106426       6.039574          3.840072
# min                     24.100000       4.000000          0.000000
# 25%                     36.500000      12.000000          6.000000
# 50%                     38.900000      16.000000          8.000000
# 75%                     41.600000      21.000000         11.000000
# max                     51.900000      35.000000         22.000000
#
#        o_4D_conversion_percentage  o_red_zone_attempts  o_red_zone_tds  \
# count                  416.000000           416.000000      416.000000
# mean                    49.700240            51.098558       28.526442
# std                     14.421604             7.689291        6.434416
# min                      0.000000            28.000000       11.000000
# 25%                     40.000000            46.000000       24.000000
# 50%                     50.000000            51.000000       28.000000
# 75%                     60.000000            56.000000       33.000000
# max                     87.500000            74.000000       47.000000
#
#        o_red_zone_td_percentage
# count                416.000000
# mean                  55.540865
# std                    7.774045
# min                   35.000000
# 25%                   50.600000
# 50%                   55.600000
# 75%                   61.100000
# max                   81.400000
#
# [8 rows x 69 columns]

# %%
combined.hist(figsize = (24,20))
plt.show()

# %%
combined1= combined.pop(combined.columns[0])

# %%
print(combined1)
# Out:
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4
#       ..
# 27    27
# 28    28
# 29    29
# 30    30
# 31    31
# Name: Unnamed: 0, Length: 416, dtype: int64

# %%
print(combined)
# Out:
#    team_abbr  points_for   yards   plays  yards_per_plbay  turnovers  \
# 0        crd       289.0  4309.0   931.0              4.6       35.0
# 1        atl       414.0  5458.0  1097.0              5.0       17.0
# 2        rav       357.0  5166.0  1018.0              5.1       20.0
# 3        buf       283.0  4878.0   954.0              5.1       39.0
# 4        car       196.0  4135.0   962.0              4.3       37.0
# ..       ...         ...     ...     ...              ...        ...
# 27       sfo       450.0  6216.0  1047.0              5.9       17.0
# 28       sea       407.0  5976.0  1044.0              5.7       23.0
# 29       tam       313.0  5894.0  1159.0              5.1       22.0
# 30       oti       298.0  5045.0   992.0              5.1       23.0
# 31       was       321.0  5615.0  1140.0              4.9       23.0
#
#     fumbles_lost  first_downs  completions  pass_attempts  ...  \
# 0           16.0        241.0        285.0          561.0  ...
# 1            8.0        353.0        361.0          577.0  ...
# 2           10.0        303.0        308.0          491.0  ...
# 3           18.0        263.0        296.0          519.0  ...
# 4           16.0        225.0        256.0          484.0  ...
# ..           ...          ...          ...            ...  ...
# 27           8.0        347.0        338.0          512.0  ...
# 28          11.0        346.0        399.0          573.0  ...
# 29          12.0        346.0        499.0          751.0  ...
# 30          12.0        277.0        285.0          456.0  ...
# 31           7.0        339.0        344.0          554.0  ...
#
#     red_zone_td_percentage  o_3D_attempts  o_3D_conversions  \
# 0                     43.2          233.0              87.0
# 1                     60.3          201.0              79.0
# 2                     49.0          229.0              87.0
# 3                     51.4          227.0              98.0
# 4                     30.3          213.0              81.0
# ..                     ...            ...               ...
# 27                    54.0          218.0              85.0
# 28                    47.3          227.0              96.0
# 29                    52.0          236.0              87.0
# 30                    64.3          225.0              77.0
# 31                    51.1          210.0              67.0
#
#     o_3D_conversion_percentage  o_4D_attempts  o_4D_conversions  \
# 0                         37.3           17.0               9.0
# 1                         39.3           17.0               9.0
# 2                         38.0           12.0               6.0
# 3                         43.2           10.0               7.0
# 4                         38.0            9.0               4.0
# ..                         ...            ...               ...
# 27                        39.0           25.0              10.0
# 28                        42.3           28.0              11.0
# 29                        36.9           24.0              14.0
# 30                        34.2           26.0              19.0
# 31                        31.9           25.0              12.0
#
#     o_4D_conversion_percentage  o_red_zone_attempts  o_red_zone_tds  \
# 0                         52.9                 69.0            27.0
# 1                         52.9                 42.0            23.0
# 2                         50.0                 40.0            17.0
# 3                         70.0                 54.0            33.0
# 4                         44.4                 66.0            32.0
# ..                         ...                  ...             ...
# 27                        40.0                 37.0            21.0
# 28                        39.3                 52.0            31.0
# 29                        58.3                 48.0            30.0
# 30                        73.1                 49.0            27.0
# 31                        48.0                 52.0            27.0
#
#     o_red_zone_td_percentage
# 0                       39.1
# 1                       54.8
# 2                       42.5
# 3                       61.1
# 4                       48.5
# ..                       ...
# 27                      56.8
# 28                      59.6
# 29                      62.5
# 30                      55.1
# 31                      51.9
#
# [416 rows x 69 columns]

# %%
combined.hist(figsize = (24,20))
plt.show()
